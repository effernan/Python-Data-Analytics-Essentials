# %% [markdown]
# # 1. Variable Assignment and Data Types

# %% [markdown]
# Let's play around with everything that we have learnt so far! Let's start our data analytics journey by creating some variables using Digital Humanities data.

# %% [markdown]
# First, please create four variables that contain the name of our four authors (Charles Dickens, Elizabeth Gaskell, Mark Twain, Edith Wharton) using **strings**. Then print all of them.

# %%
# Your code in here

# %%
# Solution
charles_dickens = "Charles Dickens"
elizabeth_gaskell = "Elizabeth Gaskell"
mark_twain = "Mark Twain"
edith_wharton = "Edith Wharton"

# %%
print(charles_dickens)
print(elizabeth_gaskell)
print(mark_twain)
print(edith_wharton)
# Out:
# Charles Dickens
# Elizabeth Gaskell
# Mark Twain
# Edith Wharton

# %% [markdown]
# Pick one variable and check the data type and length

# %%
# Your code in here

# %%
# Solution
type(charles_dickens)
# Out:
# str

# %%
len(charles_dickens)
# Out:
# 15

# %% [markdown]
# Now, please create four variables that contain the **birth dates** of our authors using **integers**. Those are:
#
#     * Charles Dickens: 1812
#     * Elizabeth Gaskell: 1810
#     * Mark Twain: 1835
#     * Edith Wharton: 1862

# %%
# Your code here

# %%
# Solution
dickens_date = 1862
gaskell_date = 1810
twain_date = 1835
wharton_date = 1862

# %% [markdown]
# Now check the data type and:
#
#     * a) convert two of them to **floats** and store that conversion into a new variable. Print it.
#     * b) convert the other two of them to **strings** and store that conversion into a new variable. Print it.
#     * c) check their data types again

# %%
#Your code in here

# %%
# Solution
dickens_float = float(dickens_date)
print(dickens_float)

gaskell_float = float(dickens_date)
print(gaskell_float)

twain_string = str(dickens_date)
print(twain_string)

wharton_string = str(dickens_date)
print(wharton_string)
# Out:
# 1862.0
# 1862.0
# 1862
# 1862

# %%
print(type(dickens_float))
print(type(gaskell_float))
print(type(twain_string))
print(type(wharton_string))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# And now:
#
#     * covert your "dickens float" variable into a string and store that conversion into a new variable. Print it.
#     * Convert your "twain string" variable into float and store that conversion into a new variable. Print it.
#     * Try to convert your previous name variable "charles dickens" (a string) both into an integer and a float. What happens?

# %%
# your code in here

# %%
# Solution

dickens_string = str(dickens_float)
print(dickens_string)

twain_float = float(twain_string)
print(twain_float)
# Out:
# 1862.0
# 1862.0

# %%
int(charles_dikens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 int(charles_dikens)
#
# NameError: name 'charles_dikens' is not defined

# %%
float(charles_dickens)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 float(charles_dickens)
#
# ValueError: could not convert string to float: 'Charles Dickens'

# %% [markdown]
# Try to run this variable down here. What is wrong? Why do you get an error message? Correct it into a correct python syntax form.

# %%
Charles Dickens = "UK Citizen"
# Out:
#   Cell In[56], line 1
#     Charles Dickens = "UK Citizen"
#             ^
# SyntaxError: invalid syntax

# %%
Charles_Dickens = "UK Citizen"
