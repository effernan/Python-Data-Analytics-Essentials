# %% [markdown]
# # 1. Lists

# %% [markdown]
# Let's create a list that includes all the novels written by Elizabeth Gaskell The novels are:
#
# * A Dark Night's Work
# * Canford,
# * Mary Barton,
# * My Lady Ludlow,
# * North and South,
# * Ruth,
# * Sylvia's Lovers,
# * Wives and Daughters.

# %%
#Your code in here

# %%
# Solution
gaskell_books = ["A Dark Night's Work", "Cranford", "Mary Barton", "My Lady Ludlow", "North and South", "Ruth", "Sylvia's Lovers",
                 "Wives and Daughters"]

# %% [markdown]
# Now:
#   * a) Check the variable data type
#   * b) Check its length
#   * c) Select the first element in the list (remember the weird Python 0 notation!). Then check the type of data of that first variable.
#   * d) Select elements 2 to 4 in that list (remember the weird Python 0 notation and the even more weird last element in list thing!).
#   * e) And now select the fith element in that list.
#   * f) Select the last element in the list.

# %%
# Your code in here

# %%
# Solution

#a
type(gaskell_books)
# Out:
# list

# %%
#b
len(gaskell_books)
# Out:
# 8

# %%
#c
print(gaskell_books[0])
type(gaskell_books[0])
# Out:
# A Dark Night's Work
# str

# %%
#d
gaskell_books[2:5]
# Out:
# ['Mary Barton', 'My Lady Ludlow', 'North and South']

# %%
#e
gaskell_books[5]
# Out:
# 'Ruth'

# %%
#f
gaskell_books[-1]
# Out:
# 'Wives and Daughters'

# %% [markdown]
# # 2. Lists Methods

# %% [markdown]
# Now:
# * a) Use the index() method to find out the position of "North and South" in the list.
# * b) Use the append() method to add one extra element to the list: "Novels".
# * c) Use the remove() method to remove that extra element "Novels" that you just included.

# %%
#Your code in here

# %%
#Solution

# %%
#a
gaskell_books.index("North and South")
# Out:
# 4

# %%
#b 
gaskell_books.append("Novels")

# %%
gaskell_books
# Out:
# ["A Dark Night's Work",
#  'Cranford',
#  'Mary Barton',
#  'My Lady Ludlow',
#  'North and South',
#  'Ruth',
#  "Sylvia's Lovers",
#  'Wives and Daughters',
#  'Novels']

# %%
#c
gaskell_books.remove("Novels")

# %%
gaskell_books
# Out:
# ["A Dark Night's Work",
#  'Cranford',
#  'Mary Barton',
#  'My Lady Ludlow',
#  'North and South',
#  'Ruth',
#  "Sylvia's Lovers",
#  'Wives and Daughters']

# %% [markdown]
# These are the dates when those books were written:
#
# * A Dark Night's Work, 1863
# * Cranford, 1853
# * Mary Barton, 1848
# * My Lady Ludlow, 1859
# * North and South, 1855
# * Ruth, 1853
# * Sylvia's Lovers, 1863
# * Wives and Daughters, 1866

# %% [markdown]
# Use the insert method to include the date 1863 after "A Dark Night's Work"

# %%
#Your code in here

# %%
#Solution

gaskell_books.insert(0, "A Dark Nights Work")

# %%
gaskell_books
# Out:
# ['A Dark Nights Work',
#  "A Dark Night's Work",
#  'Cranford',
#  'Mary Barton',
#  'My Lady Ludlow',
#  'North and South',
#  'Ruth',
#  "Sylvia's Lovers",
#  'Wives and Daughters']

# %% [markdown]
# This is an unorganized list of Gaskell's books publication dates. Use the sort method to organize it.

# %%
gaskell_book_dates = [1863, 1853, 1848, 1859, 1855, 1853, 1863, 1866]

# %%
#Your code in here

# %%
#Solution
gaskell_book_dates.sort()

# %%
gaskell_book_dates
# Out:
# [1848, 1853, 1853, 1855, 1859, 1863, 1863, 1866]

# %% [markdown]
# # 3. Dictionaries

# %% [markdown]
# Now:
# * a) Create a dictionary using the book titles of Gaskell as keys and the dates as values
# * b) Select the key "North and South" to find out when the book was published.
# * c) Check if the book "Ruth" is in our dictionary
# * d) Change the key of "A Dark Night's Work" (1863) for "error"
# * e) Remove that newly created key-value pair "error".
#
# As a reminder, these are the books and the dates.
#
# * A Dark Night's Work, 1863
# * Cranford, 1853
# * Mary Barton, 1848
# * My Lady Ludlow, 1859
# * North and South, 1855
# * Ruth, 1853
# * Sylvia's Lovers, 1863
# * Wives and Daughters, 1866

# %%
#Your code in here

# %%
# Solution

# %%
#a
gaskell_novels = {
    "A Dark Night's Work" : 1863,
    "Cranford" : 1853,
    "Mary Barton" : 1848,
    "My Lady Ludlow" : 1859,
    "North and South" : 1855,
    "Ruth" : 1853,
    "Sylvia's Lovers" : 1863,
    "Wives and Daughters" : 1866
}

# %%
gaskell_novels
# Out:
# {"A Dark Night's Work": 1863,
#  'Cranford': 1853,
#  'Mary Barton': 1848,
#  'My Lady Ludlow': 1859,
#  'North and South': 1855,
#  'Ruth': 1853,
#  "Sylvia's Lovers": 1863,
#  'Wives and Daughters': 1866}

# %%
#b
gaskell_novels["North and South"]
# Out:
# 1855

# %%
#c
"Ruth" in gaskell_novels
# Out:
# True

# %%
#d
gaskell_novels["A Dark Night's Work"] = "error"

# %%
gaskell_novels
# Out:
# {"A Dark Night's Work": 'error',
#  'Cranford': 1853,
#  'Mary Barton': 1848,
#  'My Lady Ludlow': 1859,
#  'North and South': 1855,
#  'Ruth': 1853,
#  "Sylvia's Lovers": 1863,
#  'Wives and Daughters': 1866}

# %%
#e
del gaskell_novels["A Dark Night's Work"]

# %%
gaskell_novels
# Out:
# {'Cranford': 1853,
#  'Mary Barton': 1848,
#  'My Lady Ludlow': 1859,
#  'North and South': 1855,
#  'Ruth': 1853,
#  "Sylvia's Lovers": 1863,
#  'Wives and Daughters': 1866}

# %% [markdown]
# # 4. Functions

# %% [markdown]
# Remember that unorganized list of books that we sorted previously?

# %%
gaskell_book_dates
# Out:
# [1848, 1853, 1853, 1855, 1859, 1863, 1863, 1866]

# %% [markdown]
# Create a function that takes a list of elements and returns that list sorted.

# %%
#Your code in here

# %%
# Solution
def sorted_elements(x):
    x.sort()
    return x

# %% [markdown]
# These are Charles Dickens books and dates:
#
# * A Christmas Carol, 1843
# * A Tale of Two Cities, 1859
# * Barnaby Rudge, 1841
# * Bleak House, 1853
# * David Copperfield, 1850
# * Dombey and Son, 1848
# * Great Expectations, 1861
# * Hard Times, 1854
# * Little Dorrit, 1857
# * Martin Chuzzlewit, 1844
# * Nicholas Nickleby, 1839
# * Old curiosity shop, 1841
# * Oliver Twist, 1839
# * Our Mutual Friend, 1865
# * The Battle of Life, 1846
# * The Chimes, 1844
# * The Cricket on the Hearth, 1845
# * The Haunted Man, 1848
# * The Pickwick Papers, 1837
#
# They are organized in alphabetical order but the dates are disorganized. Pass the book list variable down here to the sorted_elements function that you have just created.

# %%
books = [1843, 1859, 1841, 1853, 1850, 1848, 1861, 1854, 1857, 1844, 1839, 1841, 1839, 1865, 1856, 1844, 1845, 1848, 1837]

# %%
#Your code in here

# %%
#Solution
print(sorted_elements(books))
# Out:
# [1837, 1839, 1839, 1841, 1841, 1843, 1844, 1844, 1845, 1848, 1848, 1850, 1853, 1854, 1856, 1857, 1859, 1861, 1865]

# %% [markdown]
# And now you are in excellent shape to learn NumPy, Pandas, and Seaborn!
