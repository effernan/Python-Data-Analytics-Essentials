# %% [markdown]
# # 1. Choosing a Dataset

# %% [markdown]
# Before we start doing our data analysis, let's start importing the libraries. Please import:
#    * Pandas
#    * Numpy
#    * Matplotlib
#    * Seaborn

# %%
#Your code in here

# %%
#Solution

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# And now, please have a look at the available datasets found at print(sns.get_dataset_names()).

# %%
#Your code in here

# %%
#Solution 

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# Choose one dataset (whatever you like). Import it with the **sns.load_dataset()** function. Save that into a variable.

# %%
#Your code in here

# %%
#Solution
data_1 = sns.load_dataset("diamonds")
data_1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # 2. Doing visualizations

# %% [markdown]
# ### A) sns.jointplot()

# %% [markdown]
# Use the sns.jointplot() syntax sns.jointplot(x = "Column", y = "Year", data = variable, height = 7, space=0.15, kind = "plottype"). Do **two** plots. Choose between:
#
#    * “scatter”
#    * “kde”
#    * “hist”
#    * “hex”
#    * “reg”
#    * “resid”

# %%
# Your code in here

# %%
# Solution
sns.jointplot(x = "depth", y = "price", data = data_1, height = 7, space=0.15, kind = "scatter")
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Solution
sns.jointplot(x = "depth", y = "price", data = data_1, height = 7, space=0.15, kind = "kde")
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### b) Pairplot

# %% [markdown]
# Now, let's try to look for relationships in data. Use the sns.pairplot() function with your dataset of choice and try to see if there are some data patterns.

# %%
#Your code in here

# %%
#Solution
sns.pairplot(data_1)
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# For example, in the diamonds dataset the 2 most interesting rows are carat and price:
#    * **Carat**. We can see that the higher the carat the higher the price. The columns x (Length of the diamond), y (Width of the diamond), and z (Depth (height) of the diamond) also seem to be higher the more carats a diamond has.
#    * **Price**. We can see that, also, the higher the carat, x, y, and, z, the higher the price.
#
# What about **your** dataset?

# %% [markdown]
# ### b) Plot functions

# %% [markdown]
# And now, using the sns.plot() syntaxt:
#    * 1) Choose **two** of these available plots: sns.stripplot(),sns.swarmplot(), sns.boxplot(), sns.boxplot(), sns.violinplot(), sns.barplot(), sns.pointplot().
#    * 2) Choose **one of the plots** and use the set_style() option and choose one of these three choices: darkgrid, whitegrid, dark.
#    * 3) Now change the colour in **the other one** of those two plots to one of these categories: sns.color_palette("GnBu", 10), sns.palplot(sns.color_palette("PiYG", 10)), or sns.palplot(sns.color_palette("deep", 10)).

# %%
# Your code in here

# %%
#Solution 1
filtered_data = data_1[data_1['price'] > 10000]  # Adjust threshold as needed

# %%
#Solution 1
sns.stripplot(x = "price", y = "carat", data = data_1)
plt.xticks([])  # Hides x-ticks and labels
plt.tight_layout()
plt.show()
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x = "price", y = "carat", data = data_1, errorbar = None)
plt.xticks([])  # Hides x-ticks and labels
plt.tight_layout()
plt.show()

# %%
#Solution2
sns.set_style("darkgrid")
sns.barplot(x="price", y="carat", data=data_1, errorbar=None)
plt.xticks([])
plt.tight_layout()
plt.show()

# %%
# Solution 2
sns.stripplot(x = "price", y = "carat", data = data_1, hue = "x")
sns.color_palette("GnBu") 
plt.xticks([])  # Hides x-ticks and labels
plt.tight_layout()
plt.show()
# Out:
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\usuario\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
