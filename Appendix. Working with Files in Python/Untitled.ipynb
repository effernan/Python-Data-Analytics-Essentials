# %%
import pandas as pd

# %%
with open("great_expectations.txt", "r", encoding = "utf-8") as f:
    data = f.read()

# %%
data
# Out:
# 'Chapter I.\n\nMy father’s family name being Pirrip, and my Christian name Philip, my infant tongue could make of both names nothing longer or more explicit than Pip. So, I called myself Pip, and came to be called Pip.\n\nI give Pirrip as my father’s family name, on the authority of his tombstone and my sister,—Mrs. Joe Gargery, who married the blacksmith. As I never saw my father or my mother, and never saw any likeness of either of them (for their days were long before the days of photographs), my first fancies regarding what they were like were unreasonably derived from their tombstones. The shape of the letters on my father’s, gave me an odd idea that he was a square, stout, dark man, with curly black hair. From the character and turn of the inscription, “Also Georgiana Wife of the Above,” I drew a childish conclusion that my mother was freckled and sickly. To five little stone lozenges, each about a foot and a half long, which were arranged in a neat row beside their grave, and 
# ...

# %%
with open("data/hard_times.txt", "r", encoding = "utf-8") as f:
    data = f.read()

# %%
data
# Out:
# 'CHAPTER I\nTHE ONE THING NEEDFUL\n\n\n‘NOW, what I want is, Facts.  Teach these boys and girls nothing but\nFacts.  Facts alone are wanted in life.  Plant nothing else, and root out\neverything else.  You can only form the minds of reasoning animals upon\nFacts: nothing else will ever be of any service to them.  This is the\nprinciple on which I bring up my own children, and this is the principle\non which I bring up these children.  Stick to Facts, sir!’\n\nThe scene was a plain, bare, monotonous vault of a school-room, and the\nspeaker’s square forefinger emphasized his observations by underscoring\nevery sentence with a line on the schoolmaster’s sleeve.  The emphasis\nwas helped by the speaker’s square wall of a forehead, which had his\neyebrows for its base, while his eyes found commodious cellarage in two\ndark caves, overshadowed by the wall.  The emphasis was helped by the\nspeaker’s mouth, which was wide, thin, and hard set.  The emphasis was\nhelped by the speaker’s voice,
# ...

# %%
with open("great_expectations.txt", "w", encoding = "utf-8") as f:
    new_text = "Elena Fernández"
    f.write(new_text)
    f.close

# %%
import csv

# %%
with open("Charles_Dickens_dates.csv", "r", encoding = "utf-8") as f:
    reader = csv.reader(f)
    data = list(reader)
    
data
# Out:
# [['', 'Titles', 'Year'],
#  ['0', 'A Christmas Carol', '1843'],
#  ['1', 'A Tale of Two Cities', '1859'],
#  ['2', 'Barnaby Rudge', '1841'],
#  ['3', 'Bleak House', '1853'],
#  ['4', 'David Copperfield', '1850'],
#  ['5', 'Dombey and Son', '1848'],
#  ['6', 'Great Expectations', '1861'],
#  ['7', 'Hard Times', '1854'],
#  ['8', 'Little Dorrit', '1857'],
#  ['9', 'Martin Chuzzlewit', '1844'],
#  ['10', 'Nicholas Nickleby', '1839'],
#  ['11', 'Old curiosity shop', '1841'],
#  ['12', 'Oliver Twist', '1839'],
#  ['13', 'Our Mutual Friend', '1865'],
#  ['14', 'The Battle of Life', '1846'],
#  ['15', 'The Chimes', '1844'],
#  ['16', 'The Cricket on the Hearth', '1845'],
#  ['17', 'The Haunted Man', '1848'],
#  ['18', 'The Pickwick Papers', '1837']]

# %%
data_2[1] = ["test"]

# %%
data_2
# Out:
# [['', 'Titles', 'Year'],
#  ['test'],
#  ['1', 'A Tale of Two Cities', '1859'],
#  ['2', 'Barnaby Rudge', '1841'],
#  ['3', 'Bleak House', '1853'],
#  ['4', 'David Copperfield', '1850'],
#  ['5', 'Dombey and Son', '1848'],
#  ['6', 'Great Expectations', '1861'],
#  ['7', 'Hard Times', '1854'],
#  ['8', 'Little Dorrit', '1857'],
#  ['9', 'Martin Chuzzlewit', '1844'],
#  ['10', 'Nicholas Nickleby', '1839'],
#  ['11', 'Old curiosity shop', '1841'],
#  ['12', 'Oliver Twist', '1839'],
#  ['13', 'Our Mutual Friend', '1865'],
#  ['14', 'The Battle of Life', '1846'],
#  ['15', 'The Chimes', '1844'],
#  ['16', 'The Cricket on the Hearth', '1845'],
#  ['17', 'The Haunted Man', '1848'],
#  ['18', 'The Pickwick Papers', '1837']]

# %%
with open("data_modified.csv", "w", encoding="utf-8", newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %%
file.close()
