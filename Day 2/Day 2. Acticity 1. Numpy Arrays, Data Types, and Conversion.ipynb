# %% [markdown]
# # 1. Numpy Arrays and Data Types

# %% [markdown]
# We are going to use our dataset of Social Realism authors to practice how to build Numpy Arrays using different Data Types.

# %% [markdown]
# First, let's import the numpy library

# %%
# Your code in here

# %%
#Solution
import numpy as np

# %% [markdown]
# 1. Create a numpy array with integers where you store the number of novels written by our 4 Social Realism Authors:
#     * Charles Dickens wrote 19 novels
#     * Edith Wharton wrote 12 novels
#     * Elizabeth Gaskell wrote 8 novels
#     * Mark Twain wrote 11 novels
#
#  2. Now create a regular python list with the same information
#  3. Check the length
#  3. Check the data type of both
#  4. Select the first element of both and check its data type

# %%
# Your code in here

# %%
# Solution 
numpy_array = np.array([19, 12, 8, 11])
numpy_array
# Out:
# array([19, 12,  8, 11])

# %%
python_list = [19, 12, 8, 11]
python_list
# Out:
# [19, 12, 8, 11]

# %%
len(numpy_array)
# Out:
# 4

# %%
len(python_list)
# Out:
# 4

# %%
type(numpy_array)
# Out:
# numpy.ndarray

# %%
type(python_list)
# Out:
# list

# %%
numpy_array[0]
# Out:
# 19

# %%
type(numpy_array[0])
# Out:
# numpy.int32

# %%
python_list[0]
# Out:
# 19

# %%
type(python_list[0])
# Out:
# int

# %% [markdown]
# # 2. Conversion

# %% [markdown]
# Now:
#    * Convert the numpy_array to: a float32 and a string. Save both of them in new variables.
#    * Use .dtype to check the data type of the 3 different arrays (the integer one that you already had and the two new ones).
#    * Check the type and the lengh of both arrays
#    * Check the data type of the first element in the array in both cases
#    * If you would like to do this with a python list: how would you do it?

# %%
# Your code in here

# %%
# Solution

numpy_float = numpy_array.astype(np.float32)
numpy_float
# Out:
# array([19., 12.,  8., 11.], dtype=float32)

# %%
numpy_string = numpy_array.astype(str)
numpy_string
# Out:
# array(['19', '12', '8', '11'], dtype='<U11')

# %%
print(numpy_array.dtype)
print(numpy_string.dtype)
print(numpy_float.dtype)
# Out:
# int32
# <U11
# float32

# %%
type(numpy_float)
# Out:
# numpy.ndarray

# %%
type(numpy_float)
# Out:
# numpy.ndarray

# %%
print(len(numpy_float))
print(len(numpy_string))
# Out:
# 4
# 4

# %%
type(numpy_float[0])
# Out:
# numpy.float32

# %%
type(numpy_string[0])
# Out:
# numpy.str_

# %%
python_list
# Out:
# [19, 12, 8, 11]

# %%
python_string_list = [str(x) for x in python_list]
python_string_list
# Out:
# ['19', '12', '8', '11']

# %%
python_float_list = []

for i in python_list:
    python_float_list.append(float(i))

# %%
python_float_list
# Out:
# [19.0, 12.0, 8.0, 11.0]
